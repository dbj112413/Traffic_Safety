# %%
import os
import pandas as pd

folder_path = "./data"

csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
combined_df = pd.concat(df_list, ignore_index=True)

combined_df.to_csv("all_data.csv", index=False)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
# C:\Users\User\AppData\Local\Temp\ipykernel_27380\3009210992.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
